# %%
import math
print('Paralelepípedo\n')
print('Escreva à aresta A.')
a = float(input())
print('Escreva à aresta B.')
b = float(input())
print('Escreva à aresta C.')
c = float(input())
V = float(a*b*c)
d = float(math.sqrt(a**2+b**2+c**2))
print('Volume: %.2f'%(V), 'Diagonal: %.2f'%(d))
# Out:
# Paralelepípedo
#
# Escreva à aresta A.
# 1
# Escreva à aresta B.
# 1
# Escreva à aresta C.
# 1
# Volume: 1.00 Diagonal: 1.73
