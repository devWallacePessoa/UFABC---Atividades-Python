# %%
print("O Maior\n")
n1 = int(input())
n2 = int(input())
n3 = int(input())
formula = (n1+n2)/2+(abs(n2-n1)/2)
formula2 = (formula+n3)/2+(abs(n3-formula)/2)
print('O maior inteiro:', round(formula2))
# Out:
# O Maior
#
# -10
# -11
# -12
# O maior inteiro: -10
