# %%
print('Conversão de Temperaturas em Celsius para Fahrenheit e Kelvin. \n')
print('Escreva a temperatura em °C.')
celsius = float(input(""))
F = celsius*9/5+32
K = celsius+273.15
print(int(F), 'F')
print(int(K), 'K')
# Out:
# Conversão de Temperaturas em Celsius para Fahrenheit e Kelvin.
#
# Escreva a temperatura em °C.
# 15
# 59 F
# 288 K
