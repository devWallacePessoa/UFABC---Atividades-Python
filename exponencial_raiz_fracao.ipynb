# %%
import math
print('Exponencial, Raiz, Fração\n')
print('Escreva o numero inteiro')
a = int(input())
b = int(input())
x = float(input())
y = float(input())
resposta = (a+b**x-(math.sqrt(b))+(a+b)/(x-y))
print('expressão: %.2f' %(resposta))
# Out:
# Exponencial, Raiz, Fração
#
# 1
# 2
# 1.1
# 2.2
# expressão: -1.00
