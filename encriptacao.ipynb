# %%
x = int (input())
d1 = ((x // 1000)+1) % 10
x = x % 1000
d2 = ((x // 100)+1) % 10
x = x % 100
d3 = ((x // 10)+1) % 10
x = x % 10
d4 = (x + 1) % 10
x = x % 1000
print (str(d1)+str(d2)+str(d3)+str(d4))
# Out:
# 9999
# 0000
