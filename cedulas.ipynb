# %%
print('Cédulas')
valor = int(input())
c100= valor//100
resul100 = valor-c100*100
c50 = resul100//50
resul50 = resul100-c50*50
c20 = resul50//20
resul20 = resul50-c20*20
c10 = resul20//10
resul10 = resul20-c10*10
c5 = resul10//5
resul5 = resul10-c5*5
c2 = resul5//2
resul2 = resul5-c2*2
c1 = resul2//1
resul1 = resul2-c1*1
print(resul100,resul50,resul20,resul10,resul5,resul2,resul1)
print(c100,'de 100,',c50,'de 50,',c20,'de 20,',c10,'de 10,',c5,'de 5,',c2,'de 2,',c1,'de 1')
# Out:
# Cédulas
# 1791
# 91 41 1 1 1 1 0
# 17 de 100, 1 de 50, 2 de 20, 0 de 10, 0 de 5, 0 de 2, 1 de 1
