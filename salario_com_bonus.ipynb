# %%
print('*Calculo* de salário com bônus.\n')
print('Escreva seu nome.')
nome = str(input())
print('Escreva seu salário.')
salario = float(input())
print('Escreva seu n° de vendas.')
venda = float(input())
bonus = salario+venda*0.05
print(nome,'deve receber R$ %.2f' %(bonus))
# Out:
# *Calculo* de salário com bônus.
#
# Escreva seu nome.
# Ricardo
# Escreva seu salário.
# 0
# Escreva seu n° de vendas.
# 0
# Ricardo deve receber R$ 0.00
