# %%
print("Distância de Manhattan entre dois pontos\n")
x1 = float(input())
y1 = float(input())
x2 = float(input())
y2 = float(input())
resposta = abs(x1-x2)+abs(y1-y2)
print('%.4f'%(resposta))
# Out:
# Distância de Manhattan entre dois pontos
#
# 1
# 1
# 1
# 1
# 0.0000
